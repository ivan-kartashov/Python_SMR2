# %% [markdown]
# # 🐍 Práctica: Operadores en Python

# %% [markdown]
# ## 1️⃣ Operadores aritméticos
#
# Se utilizan para realizar operaciones matemáticas básicas con números.

# %%
# Ejemplo básico
a = 10
b = 3

print("Suma:", a + b)        # suma de a y b
print("Resta:", a - b)       # resta de a y b
print("Multiplicación:", a * b)
print("División:", a / b)
print("División entera:", a // b)
print("Resto (módulo):", a % b)
print("Potencia:", a ** b)

# %% [markdown]
# ### ✏️ Ejercicios
# 1. Crea dos variables `x` y `y` con los valores 8 y 5. Calcula su suma, resta, multiplicación y división.
# 2. Calcula el **área de un triángulo** con base 12 y altura 8.
# 3. Calcula el **resto** de dividir 45 entre 7.
# 4. Calcula 2 elevado a la 10.
# 5. Calcula el **promedio** de tres notas: 7, 9 y 10.

# %%
# ✅ Soluciones
# 1 

x = 8
y = 5
Suma = x + y
Resta = x - y
Multiplicacion = x * y
Division = x / y
print(Suma)
print(Resta)
print(Multiplicacion)
print(Division)

# 2

base = 12
altura = 8
area = (12 * 8) / 2
print("El area es", area)

# 3

a = 45
b = 7
resto = 45 % 7
print("El resto de 45 entre 7 es", resto)

# 4

dos = 2
diez = 10
elevado = 2 ** 10
print("2^10 =", elevado)

# 5

promedio = (7 + 9 + 10) / 3
print("Promedio de 7, 9 y 10 = ", promedio)
# Out:
# 13
# 3
# 40
# 1.6
# El area es 48.0
# El resto de 45 entre 7 es 3
# 2^10 = 1024
# Promedio de 7, 9 y 10 =  8.666666666666666

# %% [markdown]
# ## 2️⃣ Operadores de asignación
#
# Permiten asignar valores a variables o modificar su contenido.

# %%
# Ejemplo
x = 10
print("Valor inicial:", x)

x += 5   # equivale a x = x + 5
x *= 2   # equivale a x = x * 2
x -= 4   # equivale a x = x - 4
print("Valor final:", x)

# %% [markdown]
# ### ✏️ Ejercicios
# 1. Crea una variable `n = 50` y súmale 25 usando `+=`.
# 2. Resta 10 a `n` usando `-=`.
# 3. Multiplica `n` por 3.
# 4. Divide `n` entre 5.
# 5. Crea una variable `precio = 120` y aplícale un descuento del 20% usando operadores de asignación.

# %%
# ✅ Soluciones
# 1
n = 50
n += 25
print(n)
# 2
n -= 10
print(n)
# 3
n *= 3
print(n)
# 4
n /= 5
print(n)
# 5
precio = 120
precio *= 0.8
print("El precio con el descuento es", precio)
# Out:
# 75
# 65
# 195
# 39.0
# El precio con el descuento es 96.0

# %% [markdown]
# ## 3️⃣ Operadores de comparación
#
# Sirven para comparar valores. Devuelven `True` (verdadero) o `False` (falso).

# %%
# Ejemplo
a = 10
b = 5

print(a == b)  # ¿a es igual a b?
print(a != b)  # ¿a es distinto de b?
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)

# %% [markdown]
# ### ✏️ Ejercicios
# 1. Comprueba si 8 es igual a 8.
# 2. Comprueba si 12 es menor que 7.
# 3. Comprueba si 9 es mayor o igual que 9.
# 4. Compara dos cadenas de texto: `'hola'` y `'adiós'`.
# 5. Comprueba si el número 100 es distinto de 101.

# %%
# ✅ Soluciones
# 1
print("Es 8 igual a 8", 8 == 8)
# 2
print("Es 12 menor que 7", 12 < 7)
# 3
print("Es 9 menor o igual que 9", 9 >= 9)
# 4
print("Es hola igual a adiós", "hola" == "adiós")
# 5
print("Es 100 diferente de 101", 100 != 100)
# Out:
# Es 8 igual a 8 True
# Es 12 menor que 7 False
# Es 9 menor o igual que 9 True
# Es hola distinto a adiós True
# Es 100 diferente de 101 False

# %% [markdown]
# ## 4️⃣ Operadores lógicos
#
# Se utilizan para combinar comparaciones o expresiones booleanas.
#
# - `and`: True si **ambas** condiciones son verdaderas.
# - `or`: True si **una o ambas** condiciones son verdaderas.
# - `not`: invierte el valor lógico.

# %%
# Ejemplo
a = 10
b = 5

print((a > b) and (a < 20))  # ambas verdaderas
print((a < b) or (b == 5))   # una es verdadera
print(not (a == 10))         # invierte el resultado

# %% [markdown]
# ### ✏️ Ejercicios
# 1. Comprueba si el número 7 está entre 5 y 10 usando `and`.
# 2. Comprueba si una de dos condiciones es verdadera usando `or`.
# 3. Usa `not` para invertir el resultado de una comparación.
# 4. Comprueba si `(3 > 2)` y `(10 < 5)` son ambas verdaderas.
# 5. Crea una expresión con `and`, `or` y `not` combinados.

# %%
# ✅ Soluciones
# 1
print("¿Esta el 7 entre el 5 y 10?", (7 > 5) and (7 < 10))
# 2
print("¿Es el siete mayor que el 5 o menor que el 10? (con or)", (7 > 5) or (7 < 10))
# 3
print("¿Es el 2 igual al 10?", not (2 == 10))
# 4
print("¿Es el 3 mayor a 2 y el 10 menor que 5?", (3 > 2) and ( 10 < 5))
# 5
print("¿Es 10 igual a 10, 9 menor que diez o es el 4 menor que 5? ¿Y es el 2 menor que 1?", (10 == 10) and (9 < 10) or (4 < 5), not (2 < 1))
# Out:
# ¿Esta el 7 entre el 5 y 10? True
# ¿Es el siete mayor que el 5 o menor que el 10? (con or) True
# ¿Es el 2 igual al 10? True
# ¿Es el 3 mayor a 2 y el 10 menor que 5? False
# ¿Es 10 igual a 10, 9 menor que diez o es el 4 menor que 5? ¿Y es el 2 menor que 1? True True

# %% [markdown]
# ## 5️⃣ Operadores de pertenencia (`in`, `not in`)
#
# Comprueban si un elemento está (o no está) dentro de una lista, cadena o colección.

# %%
# Ejemplo
fruits = ["apple", "banana", "cherry"]
print("apple" in fruits)
print("orange" not in fruits)

# %% [markdown]
# ### ✏️ Ejercicios
# 1. Crea una lista `colors = ['red', 'green', 'blue']` y comprueba si `'blue'` está en la lista.
# 2. Comprueba si `'yellow'` no está en la lista.
# 3. Crea una cadena `'python'` y comprueba si `'p'` está en ella.
# 4. Comprueba si `'z'` no está en `'python'`.
# 5. Añade `'purple'` a la lista y vuelve a comprobar si está.

# %%
# ✅ Soluciones
# 1
colors = ["red", "green", "blue"]
print("Is color blue in the list colors?", "blue" in colors)
# 2
print("Is yellow in the list colors?", "yellow" not in colors)
# 3
pythstring = "python"
print("Is the letter p present in the string 'python'?", "p" in pythstring)
# 4
print("Is the letter z present in the stirng 'python'?", "z" not in pythstring)
# 5
colors.append("purple")
print("Is HERMIT PURPLE (color purple) present in colors?", "purple" in colors)
# Out:
# Is color blue in the list colors? True
# Is yellow in the list colors? True
# Is the letter p present in the string 'python'? True
# Is the letter z present in the stirng 'python'? True
# Is HERMIT PURPLE (color purple) present in colors? True

# %% [markdown]
# ## 6️⃣ Operadores de identidad (`is`, `is not`)
#
# Comprueban si dos variables **apuntan al mismo objeto** en memoria.

# %%
# Ejemplo
x = [1, 2, 3]
y = x
z = [1, 2, 3]

print(x is y)      # True, porque y es el mismo objeto que x
print(x is z)      # False, mismo contenido pero distinto objeto
print(x is not z)  # True

# %% [markdown]
# ### ✏️ Ejercicios
# 1. Crea dos listas iguales y comprueba si son el mismo objeto.
# 2. Asigna una de ellas a otra variable y comprueba si ahora son idénticas.
# 3. Usa `is not` para comprobar si dos variables son distintas en memoria.

# %%
# ✅ Soluciones
# 1
lista1 = ["2", "4", "6"]
lista2 = ["2", "4", "6"],
print("Are the variables lista1 and lista2 the same object?", lista1 is lista2) 
# 2
fastaccess = lista1
print("Is the variable fastaccess the same object as lista1?", fastaccess is lista1)
# 3
print("Is lista1 not the same object lista2?", lista1 is not lista2)
print("Is lista2 the same object as the variable fastaccess?", lista2 is fastaccess)
# Out:
# Are the variables lista1 and lista2 the same object? False
# Is the variable fastaccess the same object as lista1? True
# Is lista1 not the same object lista2? True
# Is lista2 the same object as the variable fastaccess? False

# %% [markdown]
# ## 🧩 Ejercicios de repaso
#
# 1. Calcula el doble del promedio de los números 4, 6 y 8.
# 2. Comprueba si `'o'` está en `'python'`.
# 3. Usa operadores de asignación para aumentar una variable de 5 en 5 tres veces.
# 4. Comprueba si 15 es mayor que 10 **y** menor que 20.
# 5. Comprueba si dos listas distintas tienen el mismo contenido pero no son el mismo objeto.

# %%
# ✅ Soluciones
# 1
average = (4 + 6 + 8) / 3
print("The average number beetween 4, 6 and 8 multiplied by two equals:", average * 2)
# 2
pythstring = "python"
print("Is the letter 'o' in the stirng 'python'?", "o" in pythstring)
# 3
numfive = 5
numfive *= 3
print("5 multiplied by 3 equals", numfive)
numfivealternative = 5
print("numfivealternative =", numfivealternative)
numfivealternative += 5
print("numfivealternativa =", numfivealternative)
numfivealternative += 5
print("numfivealternativa =", numfivealternative)
# 4
print("Is 15 greater than 10?", 15 > 10 )
print("Is 15 lesser than 20?", 15 < 20 )
# 5
list1 = [1, 2, 3]
list2 = [1, 2, 3]
print(list1)
print(list2)
print("Are list1 and list2 the same object?", list1 is list2)
# Out:
# The average number beetween 4, 6 and 8 multiplied by two equals: 12.0
# Is the letter 'o' in the stirng 'python'? True
# 5 multiplied by 3 equals 15
# numfivealternative = 5
# numfivealternativa = 10
# numfivealternativa = 15
# Is 15 greater than 10? True
# Is 15 lesser than 20? True
# [1, 2, 3]
# [1, 2, 3]
# Are list1 and list2 the same object? False
