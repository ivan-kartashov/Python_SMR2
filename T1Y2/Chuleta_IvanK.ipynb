# %% [markdown]
# # Ivan Kartashov
# ## Mi chuleta de Markdown
# **Negrita**
#
# *cursiva*
#
# ***Negrita Y Cursiva***
# 1. Numero 1
# 2. Numero 2
# 3. Numero 3
#
# * Viñeta
# * Viñeta
# * Viñeta
#
# > Como programar mejor
#
#
# |   Comando   |     Funcion     |
# |     ---     |    ---      |
# |   print     |imprimir text|
# |    algo     |    nose     |

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# # Mi primer programa en Python
# Este es mi primer *Hola Mundo* en un Jupyter Notebook.
# Voy a escribir una instrucción en Python y ver el resultado

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# # Pidiendo datos al usuario
# Ahora vamos a hacer un programa que pregunte tu nombre y luego te salude de manera personalizada.

# %%
nombre = input("¿Como te llamas?")
print("Encantado de conocerte,", nombre)
# Out:
# Encantado de conocerte, iVAN

# %% [markdown]
# # Suma de dos números
# Ahora vamos a escribir un programa en Python que pida dos números y muestre el resultado de sumarlos

# %%
num1 = float(input("introduzca el primer número:"))
num2 = float(input("introduce el segundo número:"))

resultado = num1 + num2
print("La suma es:", resultado)
# Out:
# La suma es: 2.0
