# %%
#Ejercicio 1.1 

marca = "Nike"
modelo = "Air max"
color = "negro"
fstring = Nike + Air max + negro
print("Zapatilla de la marca nike modelo para hacer deporte en color negro ")
# Out:
#   Cell In[58], line 6
#     fstring = Nike + Air max + negro
#                          ^
# SyntaxError: invalid syntax

# %%
#Ejercicio 1.2

usuario = float(input("introduce el nombre de usuario: "))
password = float(input("introduce la contraseña: "))

assert acceso == "True"
if usuario == "admin":
    print("acceso concedido")
elif password == "1234":
    print("acceso concedido")
else:
    print("acceso denegado")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 usuario = float(input("introduce el nombre de usuario: "))
#       2 password = float(input("introduce la contraseña: "))
#       4 assert acceso == "True"
#
# ValueError: could not convert string to float: 'admin'

# %%
#ejercicio 2.1

videojuegos = ["Fifa", "Minecraft", "Fortnite", "Valorant"]
videojuegos = str(input("Busca el juego"))
Fortnite = (input)

if Fortnite == True:
 print("Juego encontrado")
else:
 print("juego no encontrado")
break
# Out:
# juego no encontrado
#   Cell In[39], line 11
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
usuarios = ["Ana", "", "Luis", "", "Carlos"]
usuarios_validos = str(input("Estros son los usuarios validos "))
break
print(["Ana", "", "Luis", "", "Carlos"])
# Out:
#   Cell In[38], line 3
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
#Ejerciciio 3.1

def verificar_usuario(nombre):
    admin = int()
    if nombre = "admin":
       print("acceso permitido")
    else:
        print("acceso denegado")
        break
# Out:
#   Cell In[30], line 5
#     if admin = admin:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#Ejercicio 3.2

# %%
#Ejercico4.1
Juegos = "Fifa",
Juegos = "Minecraft",
Juegos = "Fortnite",

{
    "juego1": "Fifa",
    "juego2": "Minecraft",
    "juego3": "Fortnite"
}
# Out:
# {'juego1': 'Fifa', 'juego2': 'Minecraft', 'juego3': 'Fortnite'}

# %%
#ejercico 4.2
nombre = "Miguel"
rol = "programador"
{
    "nombre": "Miguel",
    "rol": "programador"
}
# Out:
# {'nombre': 'Miguel', 'rol': 'programador'}

# %%
#ejercico 4.3
Juegos = ["Fifa", "Minecraft"]
Valorant.append()
segundo_juego = "valorant"
Juegos = ["Fifa", "Minecraft", "Valorant"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 #ejercico 4.3
#       2 Juegos = ["Fifa", "Minecraft"]
# ----> 3 Valorant.append()
#       4 segundo_juego = "valorant"
#       5 Juegos = ["Fifa", "Minecraft", "Valorant"]
#
# NameError: name 'Valorant' is not defined

# %%
#ejercicio 5.1

# %%
#ejercicio 5.2
nombre = "Miguel"
rol = "programador"
{
     "Luis tiene rol usuario"
}
# Out:
#   Cell In[50], line 7
#     assert == "Luis tiene rol usuario"
#            ^
# SyntaxError: invalid syntax

# %%
#ejercicio 6.1
class Videojuego:
    self.nombre = nombre
    self.plataforma = plataforma
juego = Videojuego("Fifa", PS5) 
nombre.PS5
plataforma.Fifa
# Out:
# <>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# /tmp/ipykernel_7627/3596878864.py:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   juego = "videojuego"("Fifa", "PS5")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 #ejercicio 6.1
# ----> 2 juego = "videojuego"("Fifa", "PS5")
#
# TypeError: 'str' object is not callable

# %%
#ejercicio 6.2
juegos = ("Fifa", "Ps5")
{
   "Fifa en Ps5"
}
# Out:
# {'Fifa en Ps5'}

# %%
#ejercicoi 6.3
class video_juego:
    def __init__(self, fifa, cod, fortnite)
        super().__init__(nombre, videojuegoOnline)
        self.videojuegoOnline

# %%
Pregunta 1 : Las variables son cajas que guardan datos 
Pregunta 2 : el int que es para los numeros enteros y float que es para los numeros decimales 
Pregunta 3 : el if sirve para cuando la condicion es true
Pregunta 4 : sirve para repetir cuando la condicion sea true 
Pregunta 5 : el break lo que hace es terminar el bucle 
Pregunta 6 : Las funcioines sirven para reutilizar el codigo su funcion es para no poner mas 
Pregunta 7 : te mide la longitud 
Pregunta 8 : 
Pregunta 9 : una lista en python es una coleccion y son ordenadas y mutables y se escriben con []
Pregunta 10 : los diccionarios sirven para guaradr datos en clave valor estos se esrciben con {}
Pregunta 11 : para meter las variables dentro de un texto 
Pregunta 12 : para pedir datos 
Pregunta 13 : una clase es una plantilla para crear los objetos
Pregunta 14 : 
Pregunta 15 : para los atributos
