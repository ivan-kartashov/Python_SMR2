# %%
carton = [
    [2, 10, 34, 46, 70], # Fila 0
    [5, 17, 23, 54, 60], # Fila 1
    [8, 32, 82, 85, 90]  # Fila 2
]

for num_fila, fila in enumerate(carton):
    print(num_fila, fila)
    for num in fila:
        print(num)
# Out:
# 0 [2, 10, 34, 46, 70]
# 2
# 10
# 34
# 46
# 70
# 1 [5, 17, 23, 54, 60]
# 5
# 17
# 23
# 54
# 60
# 2 [8, 32, 82, 85, 90]
# 8
# 32
# 82
# 85
# 90
